# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests
from termcolor import colored

pd.set_option("display.max_rows", None, "display.max_columns", None)
#1. time
#2. dow jones (value and plus minus)
#3. open interest (price, oi, change, implied volitality, trade price) 
#4. Current nifty price 


from selenium import webdriver
from time import sleep
global driver
driver = webdriver.Chrome()
driver.get('https://www1.nseindia.com/live_market/dynaContent/live_watch/option_chain/optionKeys.jsp?symbolCode=-10000&symbol=NIFTY&symbol=NIFTY&instrument=-&date=-&segmentLink=17&symbolCount=2&segmentLink=17')
sleep(2)   
content = driver.page_source      
with open("nifty.txt", 'w') as f:
    f.write(content)
sleep(2)
driver.close()

# %%
f = open("nifty.txt", "r")
f = f.read()
table = pd.read_html(str(f))
data= table[1]

# %%
call_chart =[]
call_oi =[]
call_oi_change =[]
call_vol =[]
call_iv =[]
call_ltp =[]
call_netchg =[]
call_bidqty =[]
call_bid_price =[]
call_ask_price =[]
call_askqty =[]
strike =[]
put_bidqty =[]
put_bid_price =[]
put_ask_price =[]
put_askqty =[]
put_netchg =[]
put_ltp =[]
put_iv =[]
put_vol =[]
put_oi_change =[]
put_oi =[]
put_chart =[]

#####################################################################
data = data.replace("-",0) 

#####################################################################
for i in range(len(data)):
    call_chart.append(data['CALLS',        'Chart'][i])
    call_oi.append(float(data['CALLS',           'OI'][i]))
    call_oi_change.append(float(data['CALLS',   'Chng in OI'][i]))
    call_vol.append(float(data['CALLS',       'Volume'][i]))
    call_iv.append(float(data['CALLS',           'IV'][i]))
    call_ltp.append(float(data['CALLS',          'LTP'][i]))
    call_netchg.append(float(data['CALLS',     'Net Chng'][i]))
    call_bidqty.append(float(data['CALLS',       'BidQty'][i]))
    call_bid_price.append(float(data['CALLS',     'BidPrice'][i]))
    call_ask_price.append(float(data['CALLS',     'AskPrice'][i]))
    call_askqty.append(float(data['CALLS',       'AskQty'][i]))
    strike.append(float(data['Unnamed: 11_level_0', 'Strike Price'][i]))
    put_bidqty.append(float(data['PUTS',       'BidQty'][i]))
    put_bid_price.append(float(data['PUTS',     'BidPrice'][i]))
    put_ask_price.append(float(data['PUTS',     'AskPrice'][i]))
    put_askqty.append(float(data['PUTS',       'AskQty'][i]))
    put_netchg.append(float(data['PUTS',     'Net Chng'][i]))
    put_ltp.append(float(data['PUTS',          'LTP'][i]))
    put_iv.append(float(data['PUTS',           'IV'][i]))
    put_vol.append(float(data['PUTS',       'Volume'][i]))
    put_oi_change.append(float(data['PUTS',   'Chng in OI'][i]))
    put_oi.append(float(data['PUTS',           'OI'][i]))
    put_chart.append(data['PUTS',        'Chart'][i])

# %%
main = pd.DataFrame(call_oi,columns={'call_oi'})
main['call_oi_change'] = call_oi_change
main['call_vol'] =call_vol 
main['call_iv'] = call_iv
main['call_ltp'] = call_ltp
main['strike'] = strike
main['put_ltp'] = put_ltp
main['put_iv'] = put_iv
main['put_vol'] = put_vol
main['put_oi_change'] = put_oi_change
main['put_oi'] = put_oi
##################################################################################
put_total = 0
call_total = 0
for i in range(len(main["call_oi"])):
    call_total = call_total + main["call_oi"][i] 

for i in range(len(main["put_oi"])):
    put_total = put_total + main["put_oi"][i] 
    #Point of maximum pain:
################################################################################
options = []
for i in range(len(main)):
    options.append(main['call_oi'][i]+main['put_oi'][i])
options = options[:-1]

max_pain1 = 0
for i in range(len(options)):
    if(options[i] == max(options)):
        max_pain1 = main['strike'][i]

options.remove(max(options))

max_pain2 = 0
for i in range(len(options)):
    if(options[i]==max(options)):
        max_pain2 = main['strike'][i+1]

options.remove(max(options))

max_pain3 = 0
for i in range(len(options)):
    if(options[i]==max(options)):
        max_pain3 = main['strike'][i+1]

##################################################################################
for i in range(len(main)):
    options.append(main['call_oi'][i]+main['put_oi'][i])
options = options[:-1]
####################################
drop_index =[153]
for i in range(len(main)):
    if(i<48 or i>80):
        drop_index.append(i)
main = main.drop(main.index[drop_index])

# %%
#nifty 
#highlight current level
url = "https://www.ndtv.com/business/marketdata/domestic-index-nse_nifty" #url
response = requests.get(url)

soup = BeautifulSoup(response.text,'html.parser')

spans = soup.find('span', {'class' : 'senx-up-down'})
nifty = spans.text
#################################################################################
url = "https://www.ndtv.com/business/marketdata/domestic-index-nse_nifty" #url
response = requests.get(url)

soup = BeautifulSoup(response.text,'html.parser')

spans = soup.find('span', {'class' : 'senx-up-down'})
nifty = spans.text
###########################
url = "https://www.ndtv.com/business/marketdata/domestic-index-nse_nifty" #url
response = requests.get(url)

soup = BeautifulSoup(response.text,'html.parser')

nifty_point = soup.find('span', {'class' : 'green-btn'})
for i in nifty_point:     
    for j in i:
        nifty_val = float(j)
    break
nifty_point = nifty_point.text

##################################################################################

if (nifty_val >= 0):
    print("\t\t\t\t\tNifty =",end= "")
    print(colored(nifty,'green'),"\t",colored(nifty_point,'green'))
    print("\t\t\t\t\t-------------------------------")
else:
    print("\t\t\t\t\tNifty =",end= "")
    print(colored(nifty,'red'),"\t",colored(nifty_point,'red'))
    print("\t\t\t\t\t-------------------------------")
    
print("\t\t\t\t\tMaximum pain point 1 = ",end="")
print(colored(max_pain1,'blue'))
print("\t\t\t\t\tMaximum pain point 2 =",max_pain2)
print("\t\t\t\t\tMaximum pain point 3 =",max_pain3)
print("\t\t\t\t\tPUTS/CALLS =",put_total/call_total)
main.style.format({"call_oi": "{:20,.0f}", 
                    "put_oi": "{:20,.0f}", })\
                 .hide_index()\
                 .bar(subset=["call_oi",], color='lightgreen')\
                 .bar(subset=["put_oi"], color='#ff9966')
# Out:
# 					Nifty =9859.90 	 306.55(3.21%)
# 					-------------------------------
# 					Maximum pain point 1 = 9000.0
# 					Maximum pain point 2 = 9900.0
# 					Maximum pain point 3 = 9800.0
# 					PUTS/CALLS = 1.651194057442482
# <style  type="text/css" >
#     #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 13.9%, transparent 13.9%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row0_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 54.8%, transparent 54.8%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 0.0%, transparent 0.0%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row1_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 0.2%, transparent 0.2%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 3.7%, transparent 3.7%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row2_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 14.1%, transparent 14.1%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 0.2%, transparent 0.2%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row3_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 0.6%, transparent 0.6%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 2.3%, transparent 2.3%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row4_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 18.0%, transparent 18.0%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row5_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row5_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 0.9%, transparent 0.9%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 3.2%, transparent 3.2%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row6_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 21.8%, transparent 21.8%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 0.1%, transparent 0.1%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row7_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 1.3%, transparent 1.3%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 1.2%, transparent 1.2%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row8_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 21.7%, transparent 21.7%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 0.0%, transparent 0.0%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row9_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 1.7%, transparent 1.7%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row10_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 35.5%, transparent 35.5%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row10_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 100.0%, transparent 100.0%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row11_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 0.1%, transparent 0.1%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row11_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 3.9%, transparent 3.9%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row12_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 4.9%, transparent 4.9%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row12_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 25.3%, transparent 25.3%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row13_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 0.3%, transparent 0.3%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row13_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 3.1%, transparent 3.1%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row14_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 7.4%, transparent 7.4%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row14_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 24.3%, transparent 24.3%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row15_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 0.8%, transparent 0.8%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row15_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 5.8%, transparent 5.8%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row16_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 6.2%, transparent 6.2%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row16_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 39.2%, transparent 39.2%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row17_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 1.0%, transparent 1.0%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row17_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 8.5%, transparent 8.5%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row18_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 9.3%, transparent 9.3%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row18_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 38.1%, transparent 38.1%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row19_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 1.4%, transparent 1.4%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row19_col10 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ff9966 10.7%, transparent 10.7%);
#         }    #T_5fe5a6ec_8d89_11ea_a50f_a0510b0dbf73row20_
