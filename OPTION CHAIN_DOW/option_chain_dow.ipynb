# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests
pd.set_option("display.max_rows", None, "display.max_columns", None)
#1. time
#2. dow jones (value and plus minus)
#3. open interest (price, oi, change, implied volitality, trade price) 
#4. Current nifty price

# %%
#1. time
from datetime import datetime
now = datetime.now().time()
time = now 
print(time)
# Out:
# 04:47:56.461023

# %%
#CALL DATA 
url = "https://finance.yahoo.com/quote/DIA/options?date=1588896000" #url
response = requests.get(url)

soup = BeautifulSoup(response.text,'html.parser')
table = soup.find_all('table',{'class' : 'calls W(100%) Pos(r) Bd(0) Pt(0) list-options'})
call = pd.read_html(str(table))
call= call[0]

#PUT DATA 

response = requests.get(url)

soup = BeautifulSoup(response.text,'html.parser')
table = soup.find_all('table')[1] 
puts = pd.read_html(str(table))
put= puts[0]
print(put.columns)
# Out:
# Index(['Contract Name', 'Last Trade Date', 'Strike', 'Last Price', 'Bid',
#        'Ask', 'Change', '% Change', 'Volume', 'Open Interest',
#        'Implied Volatility'],
#       dtype='object')

# %%
#contract name (call)
#Last Trade Date (call)
#Open Interest(call)
#Volume(call)
#Strike(call)
#Open Interest(put)
#Volume(put)

# %%
valid_strike =[]
for i in call['Strike']:
    if (i<=260 and i>=220):
        valid_strike.append(i)

contract_name =[]
Last_Trade_Date = []
Open_Interest_call = []
Volume_call = []
Strike = []
Open_Interest_put = []
Volume_put = []

for i in range(len(call)):
    if(call['Strike'][i] in valid_strike):
        contract_name.append(call['Contract Name'][i])
        Last_Trade_Date.append(call['Last Trade Date'][i])
        Open_Interest_call.append(float(call['Open Interest'][i]))
        Volume_call.append(float(call['Volume'][i]))
        Strike.append(float(call['Strike'][i]))
        
for i in range(len(put)):
    if(put['Strike'][i] in valid_strike):
        Volume_put.append(float(put['Volume'][i]))
        Open_Interest_put.append(float(put['Open Interest'][i]))

# %%
data = pd.DataFrame(contract_name,columns={"Contract_name"})
#data['Last_Trade_Date'] = Last_Trade_Date
data['Open_Interest_call'] = Open_Interest_call
data['Volume_call'] = Volume_call
data['Strike'] = Strike
data['Volume_put'] = Volume_put
data['Open_Interest_put'] = Open_Interest_put

# %%
#2. dow jones (value and plus minus)
url = "https://www.cnbc.com/quotes/?symbol=@DJ.1" #url
response = requests.get(url)

soup = BeautifulSoup(response.text,'html.parser')

spans = soup.findAll('span', {'class' : 'last original'})
for span in spans:
    dow = span.text
    break
    
    
##################################################################################
put_total = 0
call_total = 0
for i in range(len(data["Open_Interest_call"])):
    call_total = call_total + data["Open_Interest_call"][i] 

for i in range(len(data["Open_Interest_put"])):
    put_total = put_total + data["Open_Interest_put"][i] 
##################################################################################
#Point of maximum pain:
options = []
for i in range(len(data)):
    options.append(data['Open_Interest_call'][i]+data['Open_Interest_put'][i])

max_pain = 0
for i in range(len(options)):
    if(options[i]==max(options)):
        max_pain1 = data['Strike'][i]
options.remove(max(options))

max_pain2 = 0
for i in range(len(options)):
    if(options[i]==max(options)):
        max_pain2 = data['Strike'][i]

options.remove(max(options))

max_pain3 = 0
for i in range(len(options)):
    if(options[i]==max(options)):
        max_pain3 = data['Strike'][i]
#2nd max point
##################################################################################
print("\t\t\t\t\tDOW FUTURE =",float(dow)/100)
print("\t\t\t\t\tMaximum pain point 1 =",max_pain1)
print("\t\t\t\t\tMaximum pain point 2 =",max_pain2)
print("\t\t\t\t\tMaximum pain point 3 =",max_pain3)
print("\t\t\t\t\tPUTS/CALLS =",put_total/call_total)

data.style.format({"Open_Interest_call": "{:20,.0f}", 
                            "Volume_call": "{:20,.0f}", 
                          "Volume_put": "{:20,.0f}",
                          "Open_Interest_put":"{:20,.0f}"})\
                 .hide_index()\
                 .bar(subset=["Open_Interest_call",], color='lightgreen')\
                 .bar(subset=["Open_Interest_put"], color='#ee1f5f')
# Out:
# 					DOW FUTURE = 235.84
# 					Maximum pain point 1 = 235.0
# 					Maximum pain point 2 = 242.5
# 					Maximum pain point 3 = 237.5
# 					PUTS/CALLS = 1.3425052410901468
# <style  type="text/css" >
#     #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 7.4%, transparent 7.4%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 34.1%, transparent 34.1%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row1_col1 {
#             width:  10em;
#              height:  80%;
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 2.1%, transparent 2.1%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 0.5%, transparent 0.5%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 2.6%, transparent 2.6%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 0.4%, transparent 0.4%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 1.2%, transparent 1.2%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 0.5%, transparent 0.5%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 1.6%, transparent 1.6%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 4.5%, transparent 4.5%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row5_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 12.1%, transparent 12.1%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 9.1%, transparent 9.1%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row6_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 8.2%, transparent 8.2%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 10.1%, transparent 10.1%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row7_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 32.4%, transparent 32.4%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row8_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 7.5%, transparent 7.5%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row8_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 17.0%, transparent 17.0%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row9_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 21.7%, transparent 21.7%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row9_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 100.0%, transparent 100.0%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row10_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 12.7%, transparent 12.7%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row10_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 14.7%, transparent 14.7%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row11_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 54.6%, transparent 54.6%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row11_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 26.3%, transparent 26.3%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row12_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 44.7%, transparent 44.7%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row12_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 15.0%, transparent 15.0%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row13_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 81.9%, transparent 81.9%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row13_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 30.4%, transparent 30.4%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row14_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 87.3%, transparent 87.3%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row14_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 3.6%, transparent 3.6%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row15_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 100.0%, transparent 100.0%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row15_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ee1f5f 3.0%, transparent 3.0%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row16_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightgreen 75.3%, transparent 75.3%);
#         }    #T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row16_col5 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73" ><thead>    <tr>        <th class="col_heading level0 col0" >Contract_name</th>        <th class="col_heading level0 col1" >Open_Interest_call</th>        <th class="col_heading level0 col2" >Volume_call</th>        <th class="col_heading level0 col3" >Strike</th>        <th class="col_heading level0 col4" >Volume_put</th>        <th class="col_heading level0 col5" >Open_Interest_put</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row0_col0" class="data row0 col0" >DIA200508C00220000</td>
#                         <td id="T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row0_col1" class="data row0 col1" >                  55</td>
#                         <td id="T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row0_col2" class="data row0 col2" >                   5</td>
#                         <td id="T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row0_col3" class="data row0 col3" >220</td>
#                         <td id="T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row0_col4" class="data row0 col4" >                 212</td>
#                         <td id="T_3fff77b4_8ccd_11ea_b0c8_a0510b0dbf73row0_col5" class="data row0 col5" >                 568</td>
#             </tr>
#             <tr>
